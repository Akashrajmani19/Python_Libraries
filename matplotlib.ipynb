# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
fig, ax = plt.subplots()
x = np.arange(0,10,1)
y = np.random.randint(0,10,size = 10)
ax.plot(x,y)
